# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %%
import pandas as pd

data = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv")

df = data.copy()

# %%
df.columns = df.columns.str.lower().str.replace(" ","_")
df.dropna(how="all", inplace=True)

# %%
df.sample(1)
# Out:
#       unnamed:_0 customer   state  customer_lifetime_value response  coverage  \
# 1252        1252  BH68769  Oregon              6347.497519       No  Extended
#
#      education effective_to_date employmentstatus gender  ...  \
# 1252  Bachelor            2/6/11         Employed      M  ...
#
#       number_of_open_complaints number_of_policies    policy_type  \
# 1252                        0.0                  3  Personal Auto
#
#            policy  renew_offer_type  sales_channel  total_claim_amount  \
# 1252  Personal L2            Offer2    Call Center          529.502964
#
#       vehicle_class vehicle_size vehicle_type
# 1252   Two-Door Car        Small          NaN
#
# [1 rows x 26 columns]

# %%
df.drop("unnamed:_0", axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# vehicle_type                     5482
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       10910 non-null  object
#  1   state                          10279 non-null  object
#  2   customer_lifetime_value        10910 non-null  float64
#  3   response                       10279 non-null  object
#  4   coverage                       10910 non-null  object
#  5   education                      10910 non-null  object
#  6   effective_to_date              10910 non-null  object
#  7   employmentstatus               10910 non-null  object
#  8   gender                         10910 non-null  object
#  9   income                         10910 non-null  int64
#  10  location_code                  10910 non-null  object
#  11  marital_status                 10910 non-null  object
# ...

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
df.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %%
def morethan1000(total_claim_amount):
    return df[df[total_claim_amount]>1000]

# %%
plus1k = morethan1000("total_claim_amount")

# %%
plus1k
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 30     GX19342  California              8491.465719       No   Premium
# 55     XQ74827     Arizona             19435.629240       No  Extended
# 74     LD75023      Oregon             26346.085820       No  Extended
# 77     YC54142  Washington             74228.516040       No  Extended
# 99     JY66887  California             16320.767160       No  Extended
# ...        ...         ...                      ...      ...       ...
# 10874  PD52748         NaN             10036.536340      NaN  Extended
# 10879  FK95213  California             18611.453560       No  Extended
# 10900  VN73653      Oregon              6423.739052       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#                   education effective_to_date employmentstatus gender  income  \
# ...

# %%
plus1k_final = plus1k.groupby("response").get_group("Yes")
plus1k_final.sample(5)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 10565  QO62792      Oregon              7840.165778      Yes  Extended
# 9326   MS18916  California              3508.569533      Yes  Extended
# 7989   UU42868  California              5619.689084      Yes   Premium
# 815    MA15172  California             10179.717040      Yes   Premium
# 5577   FN44127      Oregon              3508.569533      Yes  Extended
#
#                   education effective_to_date employmentstatus gender  income  \
# 10565               College           1/14/11         Employed      M   58414
# 9326                College            1/5/11    Medical Leave      M   20978
# 7989   High School or Below           1/26/11       Unemployed      M       0
# 815                Bachelor            1/5/11          Retired      F   14290
# 5577                College            1/5/11    Medical Leave      M   20978
#
# ...

# %%
lessthan1k = plus1k_final[plus1k_final["customer_lifetime_value"] < 1000]
lessthan1k.shape
# Out:
# (0, 25)

# %%
morethan1k = plus1k_final[plus1k_final["customer_lifetime_value"] > 1000]
morethan1k.shape
# Out:
# (67, 25)

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
df_yes = df.groupby("response").get_group("Yes")
df_yes.sample(3)
# Out:
#      customer       state  customer_lifetime_value response coverage  \
# 7847  FV33188  Washington              2453.570794      Yes    Basic
# 9233  TL60066  California              2397.036098      Yes    Basic
# 6681  DU39756      Nevada              4170.687348      Yes    Basic
#
#                  education effective_to_date employmentstatus gender  income  \
# 7847              Bachelor            2/9/11    Medical Leave      M   29735
# 9233  High School or Below           1/29/11          Retired      F   22283
# 6681                Master           1/17/11         Employed      F   29462
#
#       ... number_of_open_complaints number_of_policies     policy_type  \
# 7847  ...                       0.0                  1   Personal Auto
# 9233  ...                       0.0                  1   Personal Auto
# 6681  ...                       NaN                  1  Corporate Auto
#
#             policy  renew_offer_type  sales_channel  total_claim_amount  \
# ...

# %%
policy_gender = df_yes.groupby(["policy_type","gender"])

# %%
average_policy_gender = policy_gender["total_claim_amount"].mean()
average_policy_gender.reset_index()
# Out:
#       policy_type gender  total_claim_amount
# 0  Corporate Auto      F          433.738499
# 1  Corporate Auto      M          408.582459
# 2   Personal Auto      F          452.965929
# 3   Personal Auto      M          457.010178
# 4    Special Auto      F          453.280164
# 5    Special Auto      M          429.527942

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
df["number_of_policies"].value_counts()
# Out:
# number_of_policies
# 1    3864
# 2    2748
# 3    1380
# 7     532
# 9     505
# 5     498
# 4     488
# 8     461
# 6     434
# Name: count, dtype: int64

# %%
policies_state_group = df.groupby(["number_of_policies","state"])

# %%
policies_state = policies_state_group["number_of_policies"].agg(["count"])

# %%
policies_state.reset_index()
# Out:
#     number_of_policies       state  count
# 0                    1     Arizona    671
# 1                    1  California   1234
# 2                    1      Nevada    382
# 3                    1      Oregon   1016
# 4                    1  Washington    346
# 5                    2     Arizona    483
# 6                    2  California    889
# 7                    2      Nevada    259
# 8                    2      Oregon    748
# 9                    2  Washington    217
# 10                   3     Arizona    231
# 11                   3  California    475
# 12                   3      Nevada    126
# 13                   3      Oregon    372
# 14                   3  Washington     97
# 15                   4     Arizona     88
# 16                   4  California    172
# 17                   4      Nevada     33
# 18                   4      Oregon    130
# 19                   4  Washington     37
# 20                   5     Arizona    107
# ...

# %%
morethan500 = policies_state[policies_state["count"] > 500]

# %%
morethan500.reset_index()
# Out:
#    number_of_policies       state  count
# 0                   1     Arizona    671
# 1                   1  California   1234
# 2                   1      Oregon   1016
# 3                   2  California    889
# 4                   2      Oregon    748

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
education_gender_group = df.groupby(["education","gender"])

# %%
education_gender= education_gender_group["customer_lifetime_value"].agg(["max","min","median"]).rename(columns={"max":"clv max","min":"clv min","median":"clv median"}).round(2)

# %%
education_gender.reset_index()
# Out:
#               education gender   clv max  clv min  clv median
# 0              Bachelor      F  73225.96  1904.00     5640.51
# 1              Bachelor      M  67907.27  1898.01     5548.03
# 2               College      F  61850.19  1898.68     5623.61
# 3               College      M  61134.68  1918.12     6005.85
# 4                Doctor      F  44856.11  2395.57     5332.46
# 5                Doctor      M  32677.34  2267.60     5577.67
# 6  High School or Below      F  55277.45  2144.92     6039.55
# 7  High School or Below      M  83325.38  1940.98     6286.73
# 8                Master      F  51016.07  2417.78     5729.86
# 9                Master      M  50568.26  2272.31     5579.10

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
